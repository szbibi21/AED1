# %% [markdown]
# ![Algoritmos e Estrutura de Dados I](AED1_banner.jpg)

# %% [markdown]
# ## <font color='blue'>Algoritmos e Estrutura de Dados 1</font>
# ### <font color='blue'>Aula 09b - Strings</font>

# %%
# Versão da Linguagem Python
from platform import python_version
print('Versão da Linguagem Python Usada Neste Jupyter Notebook:', python_version())

# %% [markdown]
# ### Criando uma String
#
# Para criar uma string em Python você pode usar aspas simples ou duplas. Por exemplo:

# %%
# Uma única palavra
'Oi'

# %%
# Uma frase
'Criando uma string em Python'

# %%
# Podemos usar aspas duplas
"Podemos usar aspas duplas ou simples para strings em Python"

# %%
# Você pode combinar aspas duplas e simples
"Testando strings em 'Python'"

# %% [markdown]
# ### Imprimindo uma String

# %%
print ('Testando Strings em Python')

# %%
print ('Testando \n Strings \n em \n Python')

# %%
print ('\n')

# %% [markdown]
# ### Indexando Strings

# %%
# Atribuindo uma string
s = 'pyPRO - Python Profissional'

# %%
print(s)

# %% [markdown]
# > Indexação em Python começar por zero.

# %%
# Primeiro elemento da string
s[0]

# %%
s[1]

# %%
s[2]

# %%
s[3]

# %%
s[4]

# %% [markdown]
# Podemos usar um : para executar um slicing que faz a leitura de tudo até um ponto designado. Por exemplo:

# %%
# Retorna todos os elementos da string, começando pela posição 
# (lembre-se que Python começa a indexação pela posição 0),
# até o fim da string.
s[1:]

# %%
# A string original permanece inalterada
s

# %%
# Retorna tudo até a posição de índice 3
s[:3]

# %%
# Retorna tudo até a posição de índice 4
s[:5]

# %%
# Nós também podemos usar a indexação negativa e ler de trás para frente
s[-1]

# %%
# Retornar tudo, exceto a última letra
s[:-1]

# %% [markdown]
# Nós também podemos usar a notação de índice e fatiar a string em pedaços específicos (o padrão é 1).
#
# Por exemplo, podemos usar dois pontos duas vezes em uma linha e, em seguida, um número que especifica a frequência para retornar elementos.

# %%
s[::1]

# %%
s[::2]

# %%
s[::-1]

# %% [markdown]
# ### Propriedades de Strings

# %%
s

# %%
# Alterando um caracter (não é possível alterar um elemento da string)
s[0] = 'x'

# %%
# Concatenando strings
s + ' é a melhor maneira de estar preparado para o mercado de trabalho!'

# %%
s = s + ' é a melhor maneira de estar preparado para o mercado de trabalho!'

# %%
print(s)

# %%
# Podemos usar o símbolo de multiplicação para criar repetição!
letra = 'w'

# %%
letra * 3

# %% [markdown]
# ### Funções Built-in de Strings

# %%
s

# %%
# Upper Case 
s.upper()

# %%
# Lower case
s.lower()

# %%
# Dividir uma string por espaços em branco (padrão)
s.split()

# %%
# Dividir uma string por um elemento específico
s.split('a')

# %% [markdown]
# ### Funções String

# %%
s = 'seja bem-vindo(a) a Fatec e ao universo da Linguagem Python!'

# %%
s

# %%
s.capitalize()

# %%
s.count('a')

# %%
s.isalnum()

# %%
s.islower()

# %%
s.isspace()

# %%
s.endswith('o')

# %%
s = '1000'

# %%
s

# %%
type(s)

# %% [markdown]
# ### Comparando Strings

# %%
print("Python" == "R")

# %%
print("Python" == "Python")

# %% [markdown]
# ## Exercícios

# %% [markdown]
# 1- Elabore um algoritmo para ler/receber, separadamente, o primeiro nome, o nome do meio e o sobrenome de uma pessoa. Em seguida, mostre o nome completo, correspondente.

# %%
primeiro = input("Digite o primeiro nome: ")
meio = input("Digite o nome do meio: ")
sobrenome = input("Digite o sobrenome: ")

nome_completo = primeiro + " " + meio + " " + sobrenome
print("Nome completo:", nome_completo)
# Out:
# Digite o primeiro nome:  nome ]
# Digite o nome do meio:  djsf
# Digite o sobrenome:  nfdsvk
# Nome completo: nome ] djsf nfdsvk

# %% [markdown]
# 2. Faça um algoritmo que solicite uma data no formato de uma string – dd/mm/aaaa.  Mostre essa data no formato AAAAMMDD

# %%
data = input("Digite uma data no formato dd/mm/aaaa: ")

dia = data[0:2]
mes = data[3:5]
ano = data[6:10]

data_formatada = ano + mes + dia
print("Data no formato AAAAMMDD:", data_formatada)
# Out:
# Digite uma data no formato dd/mm/aaaa:  53/64/5056
# Data no formato AAAAMMDD: 50566453

# %% [markdown]
# 3. Elabore um algoritmo para determinar quantas vogais existem dentro de uma determinada frase (que deve ser recebida do usuário).

# %%
frase = input("Digite uma frase: ")

frase_minuscula = frase.lower()
vogais = "aeiou"
contador = 0

for caractere in frase_minuscula:
    if caractere in vogais:
        contador += 1

print("Quantidade de vogais na frase:", contador)
# Out:
# Digite uma frase:  hvxifdh jfbdihihs
# Quantidade de vogais na frase: 3

# %% [markdown]
# 4. Faça um algoritmo para determinar quantas palavras existem em uma determinada frase Obs: tanto a palavra, quanto a frase, devem ser informadas pelo usuário.

# %%
frase = input("Digite uma frase: ")

frase_limpa = frase.strip()
if frase_limpa == "":
    qtd_palavras = 0
else:
    palavras = frase_limpa.split()
    qtd_palavras = len(palavras)

print("Quantidade de palavras na frase:", qtd_palavras)
# Out:
# Digite uma frase:  tnbyft ymjlkgml  uyfg
# Quantidade de palavras na frase: 3

# %% [markdown]
# 5. Faça um algoritmo para determinar se um determinada palavra, digitada pelo usuário, é um palíndroma. Palíndromo: lido da direita para a esquerda, ou vice versa, representam a mesma coisa.
# Ex: AMA

# %%
palavra = input("Digite uma palavra: ")

palavra_normalizada = palavra.lower()
palavra_invertida = palavra_normalizada[::-1]

if palavra_normalizada == palavra_invertida:
    print("A palavra é um palíndromo.")
else:
    print("A palavra NÃO é um palíndromo.")
# Out:
# Digite uma palavra:  utlhkhvnl
# A palavra NÃO é um palíndromo.

# %% [markdown]
# 6. Faça um algoritmo para ler nove caracteres numéricos em uma string. Mostre o conteúdo dessa string colando pontos e virgula, respectivamente nas posições inteiras e decimais.
#
# Exemplo:
#
# Digitado> 987654321
#
# Mostrado> 9.876.543,21

# %%
num_str = input("Digite 9 caracteres numéricos (ex: 987654321): ")

inteira = num_str[:-2]
decimais = num_str[-2:]

parte_formatada = ""
tamanho = len(inteira)
resto = tamanho % 3

if resto != 0:
    parte_formatada += inteira[:resto]
    if tamanho > resto:
        parte_formatada += "."

for i in range(resto, tamanho, 3):
    parte_formatada += inteira[i:i+3]
    if i + 3 < tamanho:
        parte_formatada += "."

resultado = parte_formatada + "," + decimais
print("Mostrado >", resultado)
# Out:
# Digite 9 caracteres numéricos (ex: 987654321):  487651
# Mostrado > 4.876,51

# %% [markdown]
# ## Fim da Aula 09b
