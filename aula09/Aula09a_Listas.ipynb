# %% [markdown]
# ![Algoritmos e Estrutura de Dados I](AED1_banner.jpg)

# %% [markdown]
# ## <font color='blue'>Aula 09a - Algoritmos e Estrutura de Dados 1 </font>
# ## <font color='blue'>Estruturas de Dados (Listas)</font>

# %%
# Versão da Linguagem Python
from platform import python_version
print('Versão da Linguagem Python Usada Neste Jupyter Notebook:', python_version())

# %% [markdown]
# ## <font color='blue'>LISTAS...</font>
# ---
# ### Trabalhando com Listas

# %%
# Criando uma lista
lista_1 = ["arroz, frango, tomate, leite"]

# %%
type(lista_1)

# %%
# Imprimindo a lista
print(lista_1)

# %%
# Criando outra lista
lista_2 = ["arroz", "frango", "tomate", "leite"]

# %%
type(lista_2)

# %%
# Imprimindo a lista
print(lista_2)

# %%
# Criando lista
lista_3 = [23, 100, "Cientista de Dados"]

# %%
type(lista_3)

# %%
# Imprimindo
print(lista_3)

# %%
# Atribuindo cada valor da lista a uma variável.
item1 = lista_3[0]
item2 = lista_3[1]
item3 = lista_3[2]

# %%
# Imprimindo as variáveis
print(item1, item2, item3)

# %%
alunos = ['ana', 'pedro', 'maria']
notas = [9, 3.5, 6]

# %%
for i in range(len(alunos)):
    print(f"O(a) estudante {alunos[i]} teve nota {notas[i]}!")

# %% [markdown]
# #### Atualizando Um Item da Lista

# %%
lista_2

# %%
# Imprimindo um item da lista
lista_2[2]

# %%
# Atualizando um item da lista
lista_2[2] = "chocolate"

# %%
# Imprimindo lista alterada
lista_2

# %% [markdown]
# #### Deletando Um Item da Lista

# %%
lista_2

# %%
# Não é possível deletar um item que não existe na lista. Vai gerar erro index out of range
del lista_2[4]

# %%
# Deletando um item específico da lista
del lista_2[3]

# %%
# Imprimindo o item com a lista alterada
lista_2

# %% [markdown]
# #### Listas de Listas (Listas Aninhadas)
#
# Listas de listas são matrizes em Python.

# %%
# Criando uma lista de listas
listas = [ [1,2,3], [10,15,14], [10.1,8.7,2.3] ]

# %%
# Imprimindo a lista
print(listas)

# %%
# Atribuindo um item da lista a uma variável
a = listas[0]

# %%
listas[0][1]

# %%
a

# %%
b = a[0]

# %%
b

# %%
list1 = listas[1]

# %%
list1

# %%
valor_1_0 = list1[0]

# %%
valor_1_0

# %%
valor_1_2 = list1[2]

# %%
valor_1_2

# %%
list2 = listas[2]

# %%
list2

# %%
valor_2_0 = list2[0]

# %%
valor_2_0

# %% [markdown]
# #### Operações com Listas

# %%
# Criando uma lista aninhada (lista de listas - Matrizes)
listas = [[1,2,3], [10,15,14], [10.1,8.7,2.3]]

# %%
listas

# %%
# Atribuindo à variável a o primeiro valor da primeira lista
a = listas[0][0]

# %%
a

# %%
b = listas[1][2]

# %%
b

# %%
c = listas[0][2] + 10

# %%
c

# %%
d = 10

# %%
d

# %%
e = d * listas[2][0]

# %%
e

# %% [markdown]
# #### Concatenando Listas

# %%
lista_s1 = [34, 32, 56]

# %%
lista_s1

# %%
lista_s2 = [21, 90, 51]

# %%
lista_s2

# %%
# Concatenando listas
lista_total = lista_s1 + lista_s2

# %%
lista_total

# %% [markdown]
# ### Operador in

# %%
# Criando uma lista
lista_teste_op = [100, 2, -5, 3.4]

# %%
# Verificando se o valor 10 pertence a lista
print(10 in lista_teste_op)

# %%
# Verificando se o valor 100 pertence a lista
print(100 in lista_teste_op)

# %% [markdown]
# ### Funções Built-in

# %%
lista_s1.

# %% [markdown]
# ![Listas](listas.jpg)

# %%
# Criando uma lista
lista_numeros = [10, 20, 50, -3.4]

# %%
# Função len() retorna o comprimento da lista
len(lista_numeros)

# %%
# Função max() retorna o valor máximo da lista
max(lista_numeros)

# %%
# Função min() retorna o valor mínimo da lista
min(lista_numeros)

# %%
# Criando uma lista
lista_formacoes_dsa = ["Analista de Dados", "Cientista de Dados", "Engenheiro de Dados"]

# %%
lista_formacoes_dsa

# %%
# Adicionando um item à lista
lista_formacoes_dsa.append("Engenheiro de IA")

# %%
lista_formacoes_dsa

# %%
lista_formacoes_dsa.append("Engenheiro de IA")

# %%
lista_formacoes_dsa

# %%
lista_formacoes_dsa.count("Engenheiro de IA")

# %%
# Criando uma lista vazia
a = []

# %%
print(a)

# %%
type(a)

# %%
a.append(10)

# %%
a

# %%
a.append(50)

# %%
a

# %%
old_list = [1,2,5,10]

# %%
new_list = []

# %%
# Copiando os itens de uma lista para outra
for item in old_list:
    new_list.append(item)

# %%
lista = []
while True:
    n = int(input("Digite um valor (-1 para sair): "))
    if n == -1:
        break
    lista.append(n)

print(lista)

# %%
new_list

# %%
cidades = ['Recife', 'Manaus', 'Salvador']
cidades.extend(['Fortaleza', 'Palmas'])
print (cidades)

# %%
cidades.index('Salvador')

# %% [markdown]
# Lembre-se: em Python o índice começa por 0!

# %%
cidades.index('Rio de Janeiro')

# %%
cidades

# %%
cidades.insert(2, 110)

# %%
cidades

# %%
# Remove um item da lista
cidades.remove(110)

# %%
cidades

# %%
# Reverte a lista
cidades.reverse()

# %%
# Imprime a lista
cidades

# %%
x = [3, 4, 2, 1]

# %%
x

# %%
# Ordena a lista
x.sort()

# %%
x

# %% [markdown]
# ## <font color='blue'>EXERCÍCIOS...</font>
# ---
# ### Exercícios sobre Listas

# %% [markdown]
# 1. Faça um algoritmo que carregue um vetor de 10 elementos numéricos inteiros. Após a finalização da entrada, o algoritmo deve escrever o mesmo vetor, na ordem inversa de entrada.

# %%
vetor = []

for i in range(10):
    n = int(input(f"Digite o {i+1}º número inteiro: "))
    vetor.append(n)

print("Vetor na ordem inversa:")
for i in range(9, -1, -1):
    print(vetor[i])
# Out:
# Digite o 1º número inteiro:  4
# Digite o 2º número inteiro:  47
# Digite o 3º número inteiro:  2
# Digite o 4º número inteiro:  26
# Digite o 5º número inteiro:  2
# Digite o 6º número inteiro:  2
# Digite o 7º número inteiro:  1
# Digite o 8º número inteiro:  4
# Digite o 9º número inteiro:  4
# Digite o 10º número inteiro:  45
# Vetor na ordem inversa:
# 45
# 4
# 4
# 1
# 2
# 2
# 26
# 2
# 47
# 4

# %% [markdown]
# 2. Faça um algorimto que carregue um vetor de 5 elementos numéricos inteiros. Após a finalização da entrada, o algoritmo deve escrever o maior valor e sua posição.

# %%
vetor = []

for i in range(5):
    n = int(input(f"Digite o {i+1}º número inteiro: "))
    vetor.append(n)

maior = vetor[0]
posicao = 0

for i in range(1, 5):
    if vetor[i] > maior:
        maior = vetor[i]
        posicao = i

print("Maior valor:", maior)
print("Posição (índice):", posicao)
print("Posição (1 a 5):", posicao + 1)
# Out:
# Digite o 1º número inteiro:  5
# Digite o 2º número inteiro:  8
# Digite o 3º número inteiro:  5
# Digite o 4º número inteiro:  2
# Digite o 5º número inteiro:  7
# Maior valor: 8
# Posição (índice): 1
# Posição (1 a 5): 2

# %% [markdown]
# 3. Faça algoritmo que carregue dois vetores (listas) de cinco elementos numéricos cada um e mostre um vetor resultante na intercalação desses dois vetores

# %%
vetor1 = []
vetor2 = []

print("Digite os 5 valores do primeiro vetor:")
for i in range(5):
    n = int(input(f"Valor {i+1}: "))
    vetor1.append(n)

print("Digite os 5 valores do segundo vetor:")
for i in range(5):
    n = int(input(f"Valor {i+1}: "))
    vetor2.append(n)

vetor_intercalado = []

for i in range(5):
    vetor_intercalado.append(vetor1[i])
    vetor_intercalado.append(vetor2[i])

print("Vetor intercalado:")
print(vetor_intercalado)
# Out:
# Digite os 5 valores do primeiro vetor:
# Valor 1:  6
# Valor 2:  5
# Valor 3:  87
# Valor 4:  6
# Valor 5:  1
# Digite os 5 valores do segundo vetor:
# Valor 1:  1
# Valor 2:  8
# Valor 3:  6
# Valor 4:  5
# Valor 5:  4
# Vetor intercalado:
# [6, 1, 5, 8, 87, 6, 6, 5, 1, 4]

# %%
# Exemplo de geração de números aleatórios (randômicos) entre 1 e 60
from random import randint
a = randint(1, 60)
print(a)

# %%
# Exemplo de geração de 10 jogadas de dados
from random import randint
# Gerando 10 jogadas
for i in range (0,10):
    lado = randint(1, 6)
    print(lado, end=" ")

# %% [markdown]
# 4. Faça um Algoritmo que simule 6000 jogadas de um dado de 6 faces. Para simular o resultado utilize a função randint  Ao final, mostre a frequência de sorteio de cada uma das faces

# %%
from random import randint

qtd_jogadas = 6000

# vetor de frequências para as 6 faces (índices 0..5 → faces 1..6)
frequencias = [0, 0, 0, 0, 0, 0]

for _ in range(qtd_jogadas):
    lado = randint(1, 6)      # sorteia um número entre 1 e 6
    frequencias[lado - 1] += 1

print("Frequência de sorteio de cada face em 6000 jogadas:")
for face in range(1, 7):
    print(f"Face {face}: {frequencias[face - 1]}")
# Out:
# Frequência de sorteio de cada face em 6000 jogadas:
# Face 1: 1022
# Face 2: 998
# Face 3: 1000
# Face 4: 948
# Face 5: 995
# Face 6: 1037

# %% [markdown]
# 5. Faça um algoritmo que simule a jogada de dois dados de 6 faces. O programa deve usar randint para rolar o primeiro dado e deve usar randint novamente para rolar o segundo dado. A soma das duas faces deve ser calculada. Assim: a soma variará de 2 a 12. O programa deve rolar 30.000 vezes e mostrar a frequência com que a soma (de 2 a 12) aparecem.  Verifique se o valor 7 corresponde a 1/6 das jogadas!

# %%
from random import randint

qtd_jogadas = 30000
freq_somas = [0] * 13   # índices 0..12, usaremos apenas 2..12

for _ in range(qtd_jogadas):
    d1 = randint(1, 6)
    d2 = randint(1, 6)
    soma = d1 + d2
    freq_somas[soma] += 1

print("Frequência de cada soma (2 a 12):")
for s in range(2, 13):
    print(f"Soma {s}: {freq_somas[s]}")

freq_7 = freq_somas[7] / qtd_jogadas
print(f"\nFrequência relativa da soma 7: {freq_7:.4f}")
print(f"Ideal teórico (1/6 ≈ 0.1667)")
# Out:
# Frequência de cada soma (2 a 12):
# Soma 2: 817
# Soma 3: 1659
# Soma 4: 2492
# Soma 5: 3286
# Soma 6: 4141
# Soma 7: 5002
# Soma 8: 4212
# Soma 9: 3310
# Soma 10: 2530
# Soma 11: 1711
# Soma 12: 840
#
# Frequência relativa da soma 7: 0.1667
# Ideal teórico (1/6 ≈ 0.1667)

# %% [markdown]
# 6. Faça um algoritmo que leia uma matriz 2x2 e imprima os seus elementos na ordem:
#
# 1,1 =
#
# 1,2 =
#
# 2,1 =
#
# 2,2 =
#
# Obs: linha, coluna

# %%
# matriz 2x2: posições (linha, coluna)

matriz = [[0, 0],
          [0, 0]]

for i in range(2):
    for j in range(2):
        matriz[i][j] = float(input(f"Digite o elemento ({i+1},{j+1}): "))

print("\nElementos na ordem pedida:")
print("1,1 =", matriz[0][0])
print("1,2 =", matriz[0][1])
print("2,1 =", matriz[1][0])
print("2,2 =", matriz[1][1])
# Out:
# Digite o elemento (1,1):  5
# Digite o elemento (1,2):  7
# Digite o elemento (2,1):  9
# Digite o elemento (2,2):  6
# Elementos na ordem pedida:
# 1,1 = 5.0
# 1,2 = 7.0
# 2,1 = 9.0
# 2,2 = 6.0

# %% [markdown]
# 7. Faça um algoritmo que leia os dados de uma matriz de 4 linhas e 4 colunas, composta de elementos reais, e calcule a soma dos elementos da diagonal principal da matriz.

# %%
# matriz 4x4 e soma da diagonal principal

matriz = [[0] * 4 for _ in range(4)]

for i in range(4):
    for j in range(4):
        matriz[i][j] = float(input(f"Digite o elemento ({i+1},{j+1}): "))

soma_diagonal = 0
for i in range(4):
    soma_diagonal += matriz[i][i]

print("\nSoma dos elementos da diagonal principal:", soma_diagonal)
# Out:
# Digite o elemento (1,1):  4
# Digite o elemento (1,2):  9
# Digite o elemento (1,3):  6
# Digite o elemento (1,4):  3
# Digite o elemento (2,1):  45
# Digite o elemento (2,2):  26
# Digite o elemento (2,3):  6
# Digite o elemento (2,4):  416
# Digite o elemento (3,1):  6545
# Digite o elemento (3,2):  8
# Digite o elemento (3,3):  46
# Digite o elemento (3,4):  44
# Digite o elemento (4,1):  4,1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 7
#       5 for i in range(4):
#       6     for j in range(4):
# ----> 7         matriz[i][j] = float(input(f"Digite o elemento ({i+1},{j+1}): "))
#       9 soma_diagonal = 0
#      10 for i in range(4):
#
# ValueError: could not convert string to float: '4,1'

# %% [markdown]
# 8. Faça um algoritmo que receba uma matriz de 5x5 com números reais. Ao final o algoritmo deve calcular e mostrar a média dos elementos que estão nas linhas pares da matriz.

# %%
matriz = [[0] * 5 for _ in range(5)]

for i in range(5):
    for j in range(5):
        matriz[i][j] = float(input(f"Digite o elemento ({i+1},{j+1}): "))

soma = 0
qtde = 0

for i in [1, 3]:
    for j in range(5):
        soma += matriz[i][j]
        qtde += 1

media = soma / qtde

print(f"\nMédia dos elementos das linhas pares da matriz: {media}")
# Out:
# Digite o elemento (1,1):  5
# Digite o elemento (1,2):  45
# Digite o elemento (1,3):  44
# Digite o elemento (1,4):  5484
# Digite o elemento (1,5):  115454
# Digite o elemento (2,1):  1
# Digite o elemento (2,2):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 5
#       3 for i in range(5):
#       4     for j in range(5):
# ----> 5         matriz[i][j] = float(input(f"Digite o elemento ({i+1},{j+1}): "))
#       7 soma = 0
#       8 qtde = 0
#
# ValueError: could not convert string to float: ''

# %% [markdown]
# ## Fim da Aula 09a
